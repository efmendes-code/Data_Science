# %% [markdown]
# # Análise dos Dados dos Eleitores por Município - 2020

# %%
# Anaconda Environments - root

# %%
# Importando as bibliotecas
import pandas as pd

# %%
# Carregando o arquivo CSV
fname = 'eleitorado_municipio_2020.csv'
df = pd.read_csv(fname, sep=';', encoding='latin1')

# %%
# Mostra as 5 primeiras linhas do DF
df.head().T
# Out:
#                                           0             1          2       3  \
# NR_ANO_ELEICAO                         2020          2020       2020    2020
# CD_PAIS                                   1             1          1       1
# NM_PAIS                              Brasil        Brasil     Brasil  Brasil
# SG_REGIAO                                 N             N          N       N
# NM_REGIAO                             Norte         Norte      Norte   Norte
# SG_UF                                    AC            AC         AC      AC
# NM_UF                                  Acre          Acre       Acre    Acre
# CD_MUNICIPIO                           1120          1570       1058    1007
# NM_MUNICIPIO                     ACRELÂNDIA  ASSIS BRASIL  BRASILÉIA  BUJARI
# QTD_ELEITORES                          9169          5913      16844    9613
# QTD_ELEITORES_FEMININO                 4502          2993       8653    4736
# ...

# %%
# Tipos e quantidades
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5568 entries, 0 to 5567
# Data columns (total 43 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   NR_ANO_ELEICAO                   5568 non-null   int64
#  1   CD_PAIS                          5568 non-null   int64
#  2   NM_PAIS                          5568 non-null   object
#  3   SG_REGIAO                        5568 non-null   object
#  4   NM_REGIAO                        5568 non-null   object
#  5   SG_UF                            5568 non-null   object
#  6   NM_UF                            5568 non-null   object
#  7   CD_MUNICIPIO                     5568 non-null   int64
#  8   NM_MUNICIPIO                     5568 non-null   object
#  9   QTD_ELEITORES                    5568 non-null   int64
#  10  QTD_ELEITORES_FEMININO           5568 non-null   int64
#  11  QTD_ELEITORES_MASCULINO          5568 non-null   int64
# ...

# %%
# As 5 cidades com maior quantidade de eleitores deficientes
df.nlargest(5, 'QTD_ELEITORES_DEFICIENTE')
# Out:
#       NR_ANO_ELEICAO  CD_PAIS NM_PAIS SG_REGIAO NM_REGIAO SG_UF  \
# 5356            2020        1  Brasil        SE   Sudeste    SP
# 3658            2020        1  Brasil        SE   Sudeste    RJ
# 4988            2020        1  Brasil        SE   Sudeste    SP
# 535             2020        1  Brasil        NE  Nordeste    BA
# 4008            2020        1  Brasil         S       Sul    RS
#
#                   NM_UF  CD_MUNICIPIO    NM_MUNICIPIO  QTD_ELEITORES  ...  \
# 5356          São Paulo         71072       SÃO PAULO        8986687  ...
# 3658     Rio de Janeiro         60011  RIO DE JANEIRO        4851887  ...
# 4988          São Paulo         64777       GUARULHOS         872880  ...
# 535               Bahia         38490        SALVADOR        1897098  ...
# 4008  Rio Grande do Sul         85995   CAXIAS DO SUL         333696  ...
#
#       QTD_ELEITORES_90A94  QTD_ELEITORES_95A99  QTD_ELEITORES_MAIORIGUAL100  \
# ...

# %%
print('Eleitoras:', df['QTD_ELEITORES_FEMININO'].sum())
print('Eleitores:', df['QTD_ELEITORES_MASCULINO'].sum())
print('Não informado: ', df['QTD_ELEITORES_NAOINFORMADO'].sum())
# Out:
# Eleitoras: 77649569
# Eleitores: 70228457
# Não informado:  40457

# %%
# Criar variáveis para calcular o pencentual
tot_eleitores = df['QTD_ELEITORES'].sum()
tot_fem = df['QTD_ELEITORES_FEMININO'].sum()
tot_mas = df['QTD_ELEITORES_MASCULINO'].sum()
tot_nao = df['QTD_ELEITORES_NAOINFORMADO'].sum()

# %%
# Mostrar os valores percentualmente
print('Eleitoras:', ((tot_fem / tot_eleitores) * 100).round(2))
print('Eleitores:', ((tot_mas / tot_eleitores) * 100).round(2))
print('Não informado: ', ((tot_nao / tot_eleitores) * 100).round(2))
# Out:
# Eleitoras: 52.49
# Eleitores: 47.48
# Não informado:  0.03

# %%
# Quantos municípios tem mais homens que mulheres?
df[df['QTD_ELEITORES_MASCULINO'] > df['QTD_ELEITORES_FEMININO']].count()
# Out:
# NR_ANO_ELEICAO                     2171
# CD_PAIS                            2171
# NM_PAIS                            2171
# SG_REGIAO                          2171
# NM_REGIAO                          2171
# SG_UF                              2171
# NM_UF                              2171
# CD_MUNICIPIO                       2171
# NM_MUNICIPIO                       2171
# QTD_ELEITORES                      2171
# QTD_ELEITORES_FEMININO             2171
# QTD_ELEITORES_MASCULINO            2171
# QTD_ELEITORES_NAOINFORMADO         2171
# QTD_ELEITORES_MENOR16              2171
# QTD_ELEITORES_16                   2171
# QTD_ELEITORES_17                   2171
# QTD_ELEITORES_18                   2171
# QTD_ELEITORES_19                   2171
# QTD_ELEITORES_20                   2171
# QTD_ELEITORES_21A24                2171
# QTD_ELEITORES_25A29                2171
# QTD_ELEITORES_30A34                2171
# QTD_ELEITORES_35A39                2171
# ...

# %%
# Vamos criar uma novacoluna para indicar a relação fem/masc
df['RELACAO_FM'] = df['QTD_ELEITORES_FEMININO'] / df['QTD_ELEITORES_MASCULINO']

# %%
# Quais são os municipios com maior relação f/m
df.nlargest(5, 'RELACAO_FM').T
# Out:
#                                            3651        2892      535   \
# NR_ANO_ELEICAO                             2020        2020      2020
# CD_PAIS                                       1           1         1
# NM_PAIS                                  Brasil      Brasil    Brasil
# SG_REGIAO                                    SE          NE        NE
# NM_REGIAO                               Sudeste    Nordeste  Nordeste
# SG_UF                                        RJ          PE        BA
# NM_UF                            Rio de Janeiro  Pernambuco     Bahia
# CD_MUNICIPIO                              58122       24910     38490
# NM_MUNICIPIO                          QUEIMADOS      OLINDA  SALVADOR
# QTD_ELEITORES                             87662      282952   1897098
# QTD_ELEITORES_FEMININO                    48802      157120   1053120
# QTD_ELEITORES_MASCULINO                   38860      125832    843977
# ...

# %%
# Quais os municipios com a menor relação f/m
df.nsmallest(5, 'RELACAO_FM').T
# Out:
#                                                2395            1236  \
# NR_ANO_ELEICAO                                 2020            2020
# CD_PAIS                                           1               1
# NM_PAIS                                      Brasil          Brasil
# SG_REGIAO                                        CO              NE
# NM_REGIAO                              Centro-Oeste        Nordeste
# SG_UF                                            MT              MA
# NM_UF                                   Mato Grosso        Maranhão
# CD_MUNICIPIO                                  90921            7900
# NM_MUNICIPIO                     SERRA NOVA DOURADA  MARAJÁ DO SENA
# QTD_ELEITORES                                  1578            6531
# QTD_ELEITORES_FEMININO                          687            2853
# QTD_ELEITORES_MASCULINO                         891            3678
# QTD_ELEITORES_NAOINFORMADO                        0               0
# ...

# %%
# Vamos criar um novo dataframe só com municipios do brasil
df_brasil = df[df['CD_PAIS']==1].copy()

# %%
df_brasil.head(3).T
# Out:
#                                           0             1          2
# NR_ANO_ELEICAO                         2020          2020       2020
# CD_PAIS                                   1             1          1
# NM_PAIS                              Brasil        Brasil     Brasil
# SG_REGIAO                                 N             N          N
# NM_REGIAO                             Norte         Norte      Norte
# SG_UF                                    AC            AC         AC
# NM_UF                                  Acre          Acre       Acre
# CD_MUNICIPIO                           1120          1570       1058
# NM_MUNICIPIO                     ACRELÂNDIA  ASSIS BRASIL  BRASILÉIA
# QTD_ELEITORES                          9169          5913      16844
# QTD_ELEITORES_FEMININO                 4502          2993       8653
# QTD_ELEITORES_MASCULINO                4667          2920       8191
# QTD_ELEITORES_NAOINFORMADO                0             0          0
# ...

# %%
df.describe()
# Out:
#        NR_ANO_ELEICAO  CD_PAIS  CD_MUNICIPIO  QTD_ELEITORES  \
# count          5568.0   5568.0   5568.000000   5.568000e+03
# mean           2020.0      1.0  51465.073096   2.656582e+04
# std               0.0      0.0  29372.607385   1.564912e+05
# min            2020.0      1.0     19.000000   1.001000e+03
# 25%            2020.0      1.0  24248.000000   4.647500e+03
# 50%            2020.0      1.0  51241.500000   8.902500e+03
# 75%            2020.0      1.0  79202.500000   1.872225e+04
# max            2020.0      1.0  99074.000000   8.986687e+06
#
#        QTD_ELEITORES_FEMININO  QTD_ELEITORES_MASCULINO  \
# count            5.568000e+03             5.568000e+03
# mean             1.394568e+04             1.261287e+04
# std              8.488295e+04             7.150697e+04
# min              4.730000e+02             5.280000e+02
# 25%              2.297500e+03             2.342750e+03
# 50%              4.466500e+03             4.422000e+03
# ...

# %%
df_brasil.describe()
# Out:
#        NR_ANO_ELEICAO  CD_PAIS  CD_MUNICIPIO  QTD_ELEITORES  \
# count          5568.0   5568.0   5568.000000   5.568000e+03
# mean           2020.0      1.0  51465.073096   2.656582e+04
# std               0.0      0.0  29372.607385   1.564912e+05
# min            2020.0      1.0     19.000000   1.001000e+03
# 25%            2020.0      1.0  24248.000000   4.647500e+03
# 50%            2020.0      1.0  51241.500000   8.902500e+03
# 75%            2020.0      1.0  79202.500000   1.872225e+04
# max            2020.0      1.0  99074.000000   8.986687e+06
#
#        QTD_ELEITORES_FEMININO  QTD_ELEITORES_MASCULINO  \
# count            5.568000e+03             5.568000e+03
# mean             1.394568e+04             1.261287e+04
# std              8.488295e+04             7.150697e+04
# min              4.730000e+02             5.280000e+02
# 25%              2.297500e+03             2.342750e+03
# 50%              4.466500e+03             4.422000e+03
# ...

# %%
df.corr()
# Out:
#                                  NR_ANO_ELEICAO  CD_PAIS  CD_MUNICIPIO  \
# NR_ANO_ELEICAO                              NaN      NaN           NaN
# CD_PAIS                                     NaN      NaN           NaN
# CD_MUNICIPIO                                NaN      NaN      1.000000
# QTD_ELEITORES                               NaN      NaN      0.000081
# QTD_ELEITORES_FEMININO                      NaN      NaN      0.000537
# QTD_ELEITORES_MASCULINO                     NaN      NaN     -0.000484
# QTD_ELEITORES_NAOINFORMADO                  NaN      NaN      0.014290
# QTD_ELEITORES_MENOR16                       NaN      NaN           NaN
# QTD_ELEITORES_16                            NaN      NaN     -0.369406
# QTD_ELEITORES_17                            NaN      NaN     -0.164929
# QTD_ELEITORES_18                            NaN      NaN     -0.057777
# QTD_ELEITORES_19                            NaN      NaN     -0.024170
# ...

# %%
# plotar um gráfico de distribuição da relação f/m
df['RELACAO_FM'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# plotar um gráfico de distribuição da relação f/m
df['RELACAO_FM'].plot.hist(bins=200)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# Importando as bibliotecas gráficas
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Plotar a distruição da relação f/m
sns.distplot(df['RELACAO_FM'], bins=100, color='red')
# Out:
# C:\Users\eduardo.mendes\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='RELACAO_FM', ylabel='Density'>

# %%
# Plotar a distruição da relação f/m
sns.distplot(df['RELACAO_FM'], bins=100, color='red')

# Embelezando o gráfico
plt.title('Relação Eleitoras/Eleitores', fontsize=18)
plt.xlabel('Eleitoras/Eleitores', fontsize=14)
plt.ylabel('Frequência', fontsize=14)
# Out:
# C:\Users\eduardo.mendes\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Frequência')

# %%
# Plotar a distruição da relação f/m
sns.distplot(df['RELACAO_FM'], bins=100, color='red')

# Embelezando o gráfico
plt.title('Relação Eleitoras/Eleitores', fontsize=18)
plt.xlabel('Eleitoras/Eleitores', fontsize=14)
plt.ylabel('Frequência', fontsize=14)

plt.axvline(1.0, color='black', linestyle='--')
# Out:
# C:\Users\eduardo.mendes\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Verificar a distribuição f/m mas mostrando os pontos (municipios)
sns.swarmplot(data=df, x='NM_REGIAO', y='RELACAO_FM')
# Out:
# C:\Users\eduardo.mendes\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 52.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\eduardo.mendes\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 82.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\eduardo.mendes\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 82.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\eduardo.mendes\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 46.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
# Verificar a distribuição f/m mas mostrando os pontos (municipios)
sns.swarmplot(data=df, x='NM_REGIAO', y='RELACAO_FM')
plt.axhline(1., color='black', linestyle='--')
# Out:
# C:\Users\eduardo.mendes\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 52.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\eduardo.mendes\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 82.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\eduardo.mendes\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 82.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\eduardo.mendes\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 46.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
# Vamos plotar a quantidade total de eleitores por faixa etária
# Usando o gráfico de barro horizontal

# Primieiro vamos listar as coluns de nosso interesse
lista = ['QTD_ELEITORES_16', 'QTD_ELEITORES_17', 'QTD_ELEITORES_18', 'QTD_ELEITORES_19', 'QTD_ELEITORES_20']
tot_idade = df[lista].sum()
display(tot_idade)
# Out:
# QTD_ELEITORES_16     239961
# QTD_ELEITORES_17     790602
# QTD_ELEITORES_18    1531395
# QTD_ELEITORES_19    2299649
# QTD_ELEITORES_20    2859883
# dtype: int64

# %%
# Mostrar no gráfico de barras
tot_idade.plot.barh()
# Out:
# <AxesSubplot:>
