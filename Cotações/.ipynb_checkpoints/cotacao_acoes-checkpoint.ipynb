# %% [markdown]
# # Pega a cotação das ações em Python

# %%
# Importando as bibliotecas
from pandas_datareader import data as web # Biblioteca que vai ler o arquivo da internet
import pandas as pd
import matplotlib.pyplot as plt # Biblioteca para montagem de gráficos

# %%
# Cria um df com o valor da cotação da bovespa
cotacao_bovespa = web.DataReader('^BVSP', data_source='yahoo', start='01/01/2021', end='12/31/2021')
display(cotacao_bovespa)
# Out:
#                      High            Low           Open        Close  \
# Date
# 2021-01-04  120354.000000  118062.000000  119024.000000  118558.0000
# 2021-01-05  119790.000000  116756.000000  118835.000000  119223.0000
# 2021-01-06  120924.000000  118917.000000  119377.000000  119851.0000
# 2021-01-07  121983.000000  119101.000000  119103.000000  121956.0000
# 2021-01-08  125324.000000  122386.000000  122387.000000  125077.0000
# ...                   ...            ...            ...          ...
# 2021-12-09  106754.000000  105890.000000  106573.000000  106291.0000
# 2021-12-10  108275.000000  106296.000000  106296.000000  107617.0000
# 2021-12-13  109493.000000  107383.000000  107758.000000  107383.0000
# 2021-12-14  109148.000000  106445.000000  107387.000000  106922.0000
# 2021-12-15  107136.117188  105696.960938  106762.546875  106955.3125
#
#               Volume    Adj Close
# Date
# 2021-01-04   8741400  118558.0000
# 2021-01-05   9257100  119223.0000
# ...

# %%
# Montar o gráfico com a coluna Adj Close
cotacao_bovespa['Adj Close'].plot(figsize=(15,10))
# Mostra o gráfico
plt.show()
